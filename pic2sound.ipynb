# %%
im_rojo = "https://drive.google.com/file/d/1QGHaV8-8bah1stcxIt_RTp-Qx1egLFvR/view?usp=sharing";
im_reinhardt = "https://drive.google.com/file/d/1wyIRkW-JtnECno2QTdYgC1n0KtiNrS3s/view?usp=sharing";

# %%
import numpy as np
import pandas as pd
import cv2 as cv 
from google.colab.patches import cv2_imshow # for image display
from skimage import io
from PIL import Image 
import matplotlib.pylab as plt

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-722a8269-e5bc-40d8-a8db-8055b3ec5d02" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-722a8269-e5bc-40d8-a8db-8055b3ec5d02">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving rubens.jpg to rubens (1).jpg

# %%
for key, value in uploaded.items():
    print(key)
# Out:
# rubens.jpg

# %%
#sube imagen y despliega
img = plt.imread(key,4)

# %%
plt.imshow(img)

# %%
img.shape
# Out:
# (796, 972, 3)

# %%
[h,s,v]=rgb2hsv(i);
[N,edges] = histcounts(h(:),44100,'Normalization','probability');
figure,subplot(121)
imshow(i)
title('pintura');

subplot(222)
plot(N)
title('espectro de tono');
fs=44100;
%%
t=0:1/fs:10;
# %f=logspace(2,3,900);
f = linspace (100,1000,44100);
cosenos = cos(2*pi*f'*t);
x = N/(max(N)) * cosenos;
% soundsc([x,x,x,x,x,x],fs)
soundsc(x,fs)

subplot(224)
plot(x)
title('señal de audio');
# Out:
#   File "<ipython-input-7-c009ebea5dd7>", line 7
#     [N,edges] = histcounts(h(:),44100,'Normalization','probability');
#                              ^
# SyntaxError: invalid syntax
